# %%
import pandas as pd

titanic = pd.read_json("titanic.json")

print(titanic.columns.tolist())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %% [markdown]
# ## 1. Survival Count Chart

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic = pd.read_json("titanic.json")

sns.countplot(x='Survived', data=titanic)

plt.title("Survival Count")
plt.xlabel("Survived")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# ## 2. Age Histogram

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic = pd.read_json("titanic.json")

sns.histplot(titanic['Age'], bins=15, kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## 3. Fare Distribution

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic = pd.read_json("titanic.json")

sns.histplot(titanic['Fare'], bins=15, kde=True)

plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ## 4. Correlation Heatmap

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic = pd.read_json("titanic.json")

corr = titanic.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ## 5. Scatter Plot (Age vs Fare by Survival)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

titanic = pd.read_json("titanic.json")

sns.scatterplot(
    data=titanic,
    x="Age",
    y="Fare",
    hue="Survived"
)

plt.title("Age vs Fare by Survival")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.show()

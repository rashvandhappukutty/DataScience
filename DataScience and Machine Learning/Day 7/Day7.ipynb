# %% [markdown]
# *Compute descriptive statistics for a real dataset; identify skewed distributions; apply Z-score normalization; compute Pearson and Spearman correlations*

# %%
import pandas as pd
from scipy.stats import zscore

# Read dataset
df = pd.read_csv("Messy_Employee_dataset.csv")

# Select numeric columns
num_df = df.select_dtypes(include='number')

# 1. Descriptive Statistics
print(num_df.describe())

# 2. Identify Skewed Distributions
print("\nSkewness:")
print(num_df.skew())

# 3. Z-Score Normalization
zscore_data = num_df.apply(zscore)
print("\nZ-Score Normalized Data:")
print(zscore_data.head())

# 4. Pearson Correlation
print("\nPearson Correlation:")
print(num_df.corr())

# 5. Spearman Correlation
print("\nSpearman Correlation:")
print(num_df.corr(method='spearman'))
# Out:
#               Age         Salary         Phone
# count  809.000000     996.000000  1.020000e+03
# mean    32.484549   85155.056396 -4.942253e+09
# std      5.656860   19873.727918  2.817326e+09
# min     25.000000   50047.320000 -9.994973e+09
# 25%     25.000000   68392.487500 -7.341992e+09
# 50%     30.000000   85547.870000 -4.943997e+09
# 75%     40.000000  100974.027500 -2.520391e+09
# max     40.000000  119971.650000 -3.896086e+06
#
# Skewness:
# Age       0.017960
# Salary   -0.018825
# Phone    -0.027424
# dtype: float64
#
# Z-Score Normalized Data:
#    Age  Salary     Phone
# 0  NaN     NaN  1.168570
# 1  NaN     NaN  1.080910
# 2  NaN     NaN -0.232288
# 3  NaN     NaN  0.520522
# 4  NaN     NaN  1.191614
#
# Pearson Correlation:
#              Age    Salary     Phone
# Age     1.000000  0.091204  0.046947
# Salary  0.091204  1.000000 -0.058200
# Phone   0.046947 -0.058200  1.000000
#
# Spearman Correlation:
#              Age    Salary     Phone
# ...

# %%
import pandas as pd
from scipy.stats import zscore

# Load dataset
df = pd.read_csv("Messy_Employee_dataset.csv")

# Select numerical columns
numeric_df = df.select_dtypes(include='number')

# -----------------------------------
# 1. Descriptive Statistics
# -----------------------------------
descriptive_stats = numeric_df.describe()

print("Descriptive Statistics:")
print(descriptive_stats)

# -----------------------------------
# 2. Identify Skewed Distributions
# -----------------------------------
skewness = numeric_df.skew()

print("\nSkewness Values:")
print(skewness)

for col, value in skewness.items():
    if value > 0.5:
        print(f"{col}: Right-Skewed")
    elif value < -0.5:
        print(f"{col}: Left-Skewed")
    else:
        print(f"{col}: Approximately Symmetric")

# -----------------------------------
# 3. Z-Score Normalization
# -----------------------------------
zscore_df = numeric_df.apply(
    lambda x: zscore(x, nan_policy='omit')
)

print("\nZ-Score Normalized Data:")
print(zscore_df.head())

# -----------------------------------
# 4. Pearson Correlation
# -----------------------------------
pearson_corr = numeric_df.corr(method='pearson')

print("\nPearson Correlation Matrix:")
print(pearson_corr)

# -----------------------------------
# 5. Spearman Correlation
# -----------------------------------
spearman_corr = numeric_df.corr(method='spearman')

print("\nSpearman Correlation Matrix:")
print(spearman_corr)

# -----------------------------------
# 6. Save Results
# -----------------------------------
with pd.ExcelWriter("Statistical_Analysis.xlsx") as writer:
    descriptive_stats.to_excel(writer, sheet_name="Descriptive_Stats")
    skewness.to_frame("Skewness").to_excel(writer, sheet_name="Skewness")
    zscore_df.to_excel(writer, sheet_name="ZScore_Normalized", index=False)
    pearson_corr.to_excel(writer, sheet_name="Pearson_Correlation")
    spearman_corr.to_excel(writer, sheet_name="Spearman_Correlation")

print("\nAnalysis saved successfully!")
# Out:
# Descriptive Statistics:
#               Age         Salary         Phone
# count  809.000000     996.000000  1.020000e+03
# mean    32.484549   85155.056396 -4.942253e+09
# std      5.656860   19873.727918  2.817326e+09
# min     25.000000   50047.320000 -9.994973e+09
# 25%     25.000000   68392.487500 -7.341992e+09
# 50%     30.000000   85547.870000 -4.943997e+09
# 75%     40.000000  100974.027500 -2.520391e+09
# max     40.000000  119971.650000 -3.896086e+06
#
# Skewness Values:
# Age       0.017960
# Salary   -0.018825
# Phone    -0.027424
# dtype: float64
# Age: Approximately Symmetric
# Salary: Approximately Symmetric
# Phone: Approximately Symmetric
#
# Z-Score Normalized Data:
#         Age    Salary     Phone
# 0 -1.323911 -1.278077  1.168570
# 1       NaN -0.999328  1.080910
# 2       NaN  0.150568 -0.232288
# 3 -1.323911 -0.790589  0.520522
# 4 -1.323911  1.216767  1.191614
#
# Pearson Correlation Matrix:
#              Age    Salary     Phone
# ...

# %%
# 1. Select numerical columns
df = pd.read_csv("Messy_Employee_dataset.csv")

# %%
# 2. Descriptive Statistics
import numpy as np
num_col = df.select_dtypes(include = np.number)
print(num_col.describe())
# Out:
#               Age         Salary         Phone
# count  809.000000     996.000000  1.020000e+03
# mean    32.484549   85155.056396 -4.942253e+09
# std      5.656860   19873.727918  2.817326e+09
# min     25.000000   50047.320000 -9.994973e+09
# 25%     25.000000   68392.487500 -7.341992e+09
# 50%     30.000000   85547.870000 -4.943997e+09
# 75%     40.000000  100974.027500 -2.520391e+09
# max     40.000000  119971.650000 -3.896086e+06

# %%
import numpy as np
# 3.Identify Skewed Distributions
print("Skewness Values")
num_col = df.select_dtypes(include = np.number)
print(num_col.skew())
# Out:
# Skewness Values
# Age       0.017960
# Salary   -0.018825
# Phone    -0.027424
# dtype: float64

# %%
# 4. Apply Z-Score
from scipy.stats import zscore
zscore_df = num_col.copy()

for col in zscore_df.columns:
    zscore_df[col] = (
        zscore_df[col] - zscore_df[col].mean()
    )/ zscore_df[col].std()
print(zscore_df.head())
# Out:
#         Age    Salary     Phone
# 0 -1.323092 -1.277436  1.167997
# 1       NaN -0.998826  1.080380
# 2       NaN  0.150492 -0.232174
# 3 -1.323092 -0.790192  0.520267
# 4 -1.323092  1.216156  1.191030

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 5.Pearson Correlation
pearson_corr=num_col.corr(method='pearson')
print(pearson_corr)
plt.figure(figsize=(8,6))
sns.heatmap(
    pearson_corr,
    annot=True,
    cmap='coolwarm'
)
plt.title('Pearson Correlation')
plt.show()
# Out:
#              Age    Salary     Phone
# Age     1.000000  0.091204  0.046947
# Salary  0.091204  1.000000 -0.058200
# Phone   0.046947 -0.058200  1.000000

# %%
# 6. Spearman Correlation
import matplotlib.pyplot as plt
import seaborn as sns
spearman_corr = num_col.corr(method = "spearman")
print(spearman_corr)
plt.figure(figsize = (8,6))
sns.heatmap(spearman_corr, annot = True, cmap = 'viridis')
plt.title("Spearman Correlation")
plt.show()
# Out:
#              Age    Salary     Phone
# Age     1.000000  0.091261  0.046252
# Salary  0.091261  1.000000 -0.057097
# Phone   0.046252 -0.057097  1.000000

# %%
# 7. Compare Pearson & Spearman
import pandas as pd

pearson_corr = num_col.corr(method='pearson')
spearman_corr = num_col.corr(method='spearman')

comparison = pd.DataFrame({
    'Pearson': pearson_corr.stack(),
    'Spearman': spearman_corr.stack()
})

print(comparison)
# Out:
#                 Pearson  Spearman
# Age    Age     1.000000  1.000000
#        Salary  0.091204  0.091261
#        Phone   0.046947  0.046252
# Salary Age     0.091204  0.091261
#        Salary  1.000000  1.000000
#        Phone  -0.058200 -0.057097
# Phone  Age     0.046947  0.046252
#        Salary -0.058200 -0.057097
#        Phone   1.000000  1.000000

# %% [markdown]
# ---

# %%
import pandas as pd
import seaborn as sns
# Load Titanic dataset
df = sns.load_dataset("titanic")
print(df.head())
print(df.shape)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#Create Problems
df.loc[0,'embark_town']='southampton'
df.loc[0,'embark_town']='SOUTHAMPTON'
df.loc[0,'embark_town']='Southampton'
print(df['embark_town'].unique())
# Out:
# ['Southampton' 'Cherbourg' 'Queenstown' nan]

# %%
#UNIQUE VALUES
df['embark_town'] = df['embark_town'].str.title()
print(df['embark_town'].unique())
# Out:
# ['Southampton' 'Cherbourg' 'Queenstown' nan]

# %%
print(df['embark_town'].isnull().sum())
# Out:
# 2

# %%
df['embark_town'] = df['embark_town'].fillna("Kingstown")

# %%
print(df['embark_town'].unique())
# Out:
# ['Southampton' 'Cherbourg' 'Queenstown' 'Kingstown']

# %%
# Create Find Duplicate Rows
duplicate_rows=df.iloc[:5]
df_dup=pd.concat([df,duplicate_rows])
print(df_dup.shape)
# Out:
# (896, 15)

# %%
# Duplicate Rows
print(df_dup.duplicated().sum())
# Out:
# 112

# %%
# View Duplicate Rows
df_dup[df_dup.duplicated()]
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 47         1       3  female   NaN      0      0   7.7500        Q  Third
# 76         0       3    male   NaN      0      0   7.8958        S  Third
# 77         0       3    male   NaN      0      0   8.0500        S  Third
# 87         0       3    male   NaN      0      0   8.0500        S  Third
# 95         0       3    male   NaN      0      0   8.0500        S  Third
# ..       ...     ...     ...   ...    ...    ...      ...      ...    ...
# 0          0       3    male  22.0      1      0   7.2500        S  Third
# 1          1       1  female  38.0      1      0  71.2833        C  First
# 2          1       3  female  26.0      0      0   7.9250        S  Third
# 3          1       1  female  35.0      1      0  53.1000        S  First
# 4          0       3    male  35.0      0      0   8.0500        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# ...

# %%
# Remove Duplicates
df_dup = df_dup.drop_duplicates()
print(df_dup.duplicated().sum())
# Out:
# 0

# %%
#Create type
df.loc[0,'embark_town']
# Out:
# 'Southampton'

# %%
#Fix types
df['embark_town']=df['embark_town'].replace({
    'Southampton':'Southampton',
    'Southhampton':'Southampton'
})
#verify
print(df['embark_town'].value_counts())
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Kingstown        2
# Name: count, dtype: int64

# %%
# Detect Possible Types
print(sorted(df['embark_town'].dropna().unique()))
# Out:
# ['Cherbourg', 'Kingstown', 'Queenstown', 'Southampton']

# %%
df.loc[0,'age'] = 240
df.loc[1,'age'] = 300
#Detect unusual values
df['age'].describe()
# Out:
# count    714.000000
# mean      30.371387
# std       19.362012
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.750000
# max      300.000000
# Name: age, dtype: float64

# %%
# Fix unit Mismatch
# cONVER MONTHS TO YEARS.
df.loc[df['age'] > 120,'age'] =(
    df.loc[df['age'] > 120 , 'age'] /12
)
# verify
df['age'].describe()
# Out:
# count    714.000000
# mean      29.678109
# std       14.525902
# min        0.420000
# 25%       20.000000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
df['survived_label'] = df['survived'].map({
    0 : 'No',
    1 : 'Yes'
})
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  20.0      1      0   7.2500        S  Third
# 1         1       1  female  25.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone survived_label
# 0    man        True  Southampton    no  False             No
# 1  woman       False    Cherbourg   yes  False            Yes
# 2  woman       False  Southampton   yes   True            Yes
# 3  woman       False  Southampton   yes  False            Yes
# 4    man        True  Southampton    no   True             No

# %%
# Calculate the proportion of missing values for each column in the DataFrame\
df.isnull().mean()
# Out:
# survived          0.000000
# pclass            0.000000
# sex               0.000000
# age               0.198653
# sibsp             0.000000
# parch             0.000000
# fare              0.000000
# embarked          0.002245
# class             0.000000
# who               0.000000
# adult_male        0.000000
# embark_town       0.000000
# alive             0.000000
# alone             0.000000
# survived_label    0.000000
# dtype: float64

# %%
# Remove
df.drop(columns=['deck'], inplace=True, errors='ignore')  # errors='ignore' prevents KeyError
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  20.0      1      0   7.2500        S  Third
# 1         1       1  female  25.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone survived_label
# 0    man        True  Southampton    no  False             No
# 1  woman       False    Cherbourg   yes  False            Yes
# 2  woman       False  Southampton   yes   True            Yes
# 3  woman       False  Southampton   yes  False            Yes
# 4    man        True  Southampton    no   True             No

# %%
# checking ,issing values
df.isnull().sum()
# Out:
# survived            0
# pclass              0
# sex                 0
# age               177
# sibsp               0
# parch               0
# fare                0
# embarked            2
# class               0
# who                 0
# adult_male          0
# embark_town         0
# alive               0
# alone               0
# survived_label      0
# dtype: int64

# %% [raw]
# # Method 1 : Mean Imputation
# # Replace missing values with the average value.
# df['age'] = df['age'].fillna(df['age'].mean())
# df.head(20)

# %%
print(df['embarked'].isnull().sum())
# Out:
# 2

# %%
# Apply forward fill
df['embarked_ffill'] = df['embarked'].ffill()
# check Missing values
print(df['embarked_ffill'].isnull().sum())
# Out:
# 0

# %%
import pandas as pd
import numpy as np

data = {
    'age':[22,25,np.nan , 24,23],
    'fare': [7.25,8.05,7.90,8.00,7.50]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     age  fare
# 0  22.0  7.25
# 1  25.0  8.05
# 2   NaN  7.90
# 3  24.0  8.00
# 4  23.0  7.50

# %%
# Apply KNN Imputation
from sklearn.impute import  KNNImputer
KNN = KNNImputer(n_neighbors = 3)
df_KNN = pd.DataFrame(
    KNN.fit_transform(df),
    columns = df.columns)
print(df_KNN)
#sklearn -> scikit-learn library for machine learning and data prepration
# Impute -> Module for handling missing values
# KNN Imputer -> Class that fills missing values using the K-Nearest Neighbor
# fit_transform(df) -> Learns form the data and fills missing values 
# Converts the result back into a pandas Dataframe
# Out:
#     age  fare
# 0  22.0  7.25
# 1  25.0  8.05
# 2  24.0  7.90
# 3  24.0  8.00
# 4  23.0  7.50

# %%
# Check Missing values
import pandas as pd
import seaborn as sns
from sklearn.impute import KNNImputer
# Load Titanic dataset
df = sns.load_dataset("titanic")
# forward fill for embarked
df['embarked_ffill'] = df['embarked'].ffill()
#KNN Imputation for age
cols = ['age','fare','sibsp','parch','pclass']
imputer = KNNImputer(n_neighbors = 5)
df[cols] = imputer.fit_transform(df[cols])
print(df.isnull().sum())
# Out:
# survived            0
# pclass              0
# sex                 0
# age                 0
# sibsp               0
# parch               0
# fare                0
# embarked            2
# class               0
# who                 0
# adult_male          0
# deck              688
# embark_town         2
# alive               0
# alone               0
# embarked_ffill      0
# dtype: int64

# %%
# Backward fill
# df.fillna(method = 'bfill',inplace = True)
"""Encoding:
-> Machine Learning models work with numbers,not text
ex: sex
  -> male,female,male
  -> A models cannot directly understand 'male' and 'female'
  -> We convert categories into numbers encoding
types:
1. Label Encoding(ordinal data)
2. One hot encoding (norminal data)
3. Targeted encoding
"""
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
# Load Titanic dataset
df = sns.load_dataset('titanic')
# Label Encoding
le = LabelEncoder()
df['sex_encoded'] = le.fit_transform(
    df['sex']
)
# One-Hot Encoding
df = pd.get_dummies(df,columns = ['embarked'],drop_first = True)
# Target Encoding
target_map = df.groupby('pclass')['survived'].mean()
df['class_target'] = (df['pclass'].map(target_map))
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class    who  \
# 0         0       3    male  22.0      1      0   7.2500  Third    man
# 1         1       1  female  38.0      1      0  71.2833  First  woman
# 2         1       3  female  26.0      0      0   7.9250  Third  woman
# 3         1       1  female  35.0      1      0  53.1000  First  woman
# 4         0       3    male  35.0      0      0   8.0500  Third    man
#
#    adult_male deck  embark_town alive  alone  sex_encoded  embarked_Q  \
# 0        True  NaN  Southampton    no  False            1       False
# 1       False    C    Cherbourg   yes  False            0       False
# 2       False  NaN  Southampton   yes   True            0       False
# 3       False    C  Southampton   yes  False            0       False
# 4        True  NaN  Southampton    no   True            1       False
#
#    embarked_S  class_target
# 0        True      0.242363
# 1       False      0.629630
# 2        True      0.242363
# ...

# %%
#Feature Scaling
''' >> transforms numerical features to a similar scale
>> Many ML algorithms calculate distance,so fare can dominate the model
# METHOD1: MiniMaxScaler --->sensitive to outliers , values between 0 and 1
# METHOD2: StandardScaler --->here outlier is applicable , works well for normally distributed data
Best for : Logistic Regression,SVM,PCA,KNN,Linear Regression
# METHOD3: RobustScaler  ---->uses Median and IQR instead of Mean and SD,handels outliers well,values not limited to 0-1
'''
# 1. MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[['age_minmax','fare_minmax']] = scaler.fit_transform(
    df[['age','fare']]
)
df[['age_minmax','fare_minmax']].head()
# Out:
#    age_minmax  fare_minmax
# 0    0.271174     0.014151
# 1    0.472229     0.139136
# 2    0.321438     0.015469
# 3    0.434531     0.103644
# 4    0.434531     0.015713

# %%
# MinMax Chart
import matplotlib.pyplot as plt
plt.hist(df['fare'].dropna(),bins = 30)
plt.title("Original Fare")
plt.show()
plt.hist(df['fare_minmax'], bins = 30)
plt.title("MinMax Scaled Fare")
plt.show()

# %%
# 3. Robust Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['age_std','fare_std']] = scaler.fit_transform(
    df[['age','fare']]
)
df[['age_std','fare_std']].head()
# Out:
#     age_std  fare_std
# 0 -0.530377 -0.502445
# 1  0.571831  0.786845
# 2 -0.254825 -0.488854
# 3  0.365167  0.420730
# 4  0.365167 -0.486337

# %%
# 3. Robust Scaler
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
df[['age_robust','fare_robust']] = scaler.fit_transform(
    df[['age','fare']]
)
df[['age_std','fare_std']].head()
